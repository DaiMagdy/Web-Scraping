# %%
import requests
from bs4 import BeautifulSoup

all_jobs = []  

for page in range(4):  
    url = f'https://wuzzuf.net/search/jobs?a=spbg&q=machine%20learning&start={page}'
    Response = requests.get(url)
    soup = BeautifulSoup(Response.text, 'lxml')
    
    jobs = soup.find_all('div', class_='css-ghe2tq e1v1l3u10')
    all_jobs.extend(jobs) 


print(f"The Server's Response = {Response}")
print(f'Total jobs found across all pages: {len(all_jobs)}\n')


for job in all_jobs:
    job_title = job.find('h2', class_='css-193uk2c')
    job_title = job_title.text.strip() if job_title else "N/A"

    company_name = job.find('a', class_='css-ipsyv7')
    company_name = company_name.text.strip() if company_name else "N/A"

    site = job.find('span', class_='css-16x61xq')
    site = site.text.strip() if site else "N/A"

    skills_list = job.find_all('a', class_='css-5x9pm1')
    skills = ', '.join([skill.text.replace('·', '').strip() for skill in skills_list if skill.text.strip()]) if skills_list else "N/A"

    puplished_date = job.find('div', class_='css-eg55jf')
    puplished_date = puplished_date.text.strip() if puplished_date else "N/A"

    exp_anchor = job.find('a', class_='css-o171kl', string='Experienced')
    if exp_anchor:
        experience_span = exp_anchor.find_next('span')
        experience = experience_span.text.replace('·', '').strip() if experience_span else "N/A"
    else:
        experience = "N/A"

    print(f'''
    Job title is     : {job_title} 
    Company name is  : {company_name} in {site} 
    Experience years : {experience} 
    Skills are       : {skills} 
    Published in     : {puplished_date}
    ''')
    print('------------------------------------------------------------------------------------------------------------------\n')
# Out:
# The Server's Response = <Response [200]>
# Total jobs found across all pages: 56
#
#
#     Job title is     : AI / Machine Learning Developer
#     Company name is  : Roboeyetec - in Nasr City, Cairo, Egypt
#     Experience years : 3 - 5 Yrs of Exp
#     Skills are       : Machine Learning Developer, Machine Learning, AI, Software Development
#     Published in     : 8 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Senior Machine Learning
#     Company name is  : Zeidex - in Giza, Egypt
#     Experience years : 3 - 5 Yrs of Exp
#     Skills are       : Machine Learning, Cloud Computing, PyTorch, Data Engineering
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Senior Quantitative Analyst
#     Company name is  : Confidential - in Cairo, Egypt
#     Experience years : 7+ Yrs of Exp
#     Skills are       : Statistical Analysis, Machine Learning, Programming (Python, R, C++, MATLAB), Quantitative Research, Backtesting, Risk Management, Data Analysis
#     Published in     : 11 hours ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Data Science Instructor
#     Company name is  : EpsilonAI - in Nasr City, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Data Science, Computer Science, Computer Engineering, Python, Machine Learning, Deep Learning, Artificial Intelligence (AI)
#     Published in     : 7 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : AI Researcher / AI Engineer
#     Company name is  : Arabian Data - in Nasr City, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Machine Learning, Natural Language Processing, Deep Learning, Artificial Intelligence, Computer Vision, Data Engineering, Statistical Modeling
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Software Engineer
#     Company name is  : Arabian Data - in Nasr City, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Software Development, Data Engineering, Python, Machine Learning, ETL Processes, Front-End Development, front-end web development, Back-End Development
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Technical Lead
#     Company name is  : Zeidex - in Maadi, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Information Technology (IT), Software, Software Development, Development, Engineering, Software Engineering, Architecture
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Artificial Intelligence & Machine Learning Intern
#     Company name is  : Aajil - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : Artificial Intelligence, Computer Science, Information Technology (IT), Software Engineering, Software Development, Computer Engineering, Engineering
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : AI Engineer - Travel Tech
#     Company name is  : Rahala - in Mohandessin, Giza, Egypt
#     Experience years : 2+ Yrs of Exp
#     Skills are       : AI, Computer Science, Data Science, Engineering, Information Technology (IT), Machine Learning, Python
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Data Scientist
#     Company name is  : Lumin - in Sheikh Zayed, Giza, Egypt
#     Experience years : 3+ Yrs of Exp
#     Skills are       : Computer Science, Analysis, Mathematics, Data Analysis, Hadoop, Data Science, Information Technology (IT)
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Data Scientist
#     Company name is  : Egabi FSI  - in Sheraton, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Computer Science, Data Mining, Data Science, data scientist, Hadoop, Machine Learning, Python, SQL
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Machine Learning Engineer
#     Company name is  : EPAM Systems - in Dubai, United Arab Emirates
#     Experience years : Machine Learning
#     Skills are       : Machine Learning, Computer Science, Information Technology (IT), Python, Software Engineering, Computer Engineering, Engineering
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : AI Engineer
#     Company name is  : ProVision Group - in Maadi, Cairo, Egypt
#     Experience years : 2 - 7 Yrs of Exp
#     Skills are       : AI, Computer Vision, Data Science, Machine Learning
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Learning & Development Specialist
#     Company name is  : Sungrow MENA & Central Asia - in Dubai, United Arab Emirates
#     Experience years : Learning
#     Skills are       : Education, Learning, Training, Information Technology (IT), Computer Science, Teaching, E-Learning
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Learning & Development Manager - LXR Eastern Mangroves Abu Dhabi (Pre-Opening)
#     Company name is  : Hilton - in Dubai, United Arab Emirates
#     Experience years : N/A
#     Skills are       : Education, Learning, Training, Information Technology (IT), Computer Science, Teaching, E-Learning
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : AI Engineer
#     Company name is  : Sprint Star - in Cairo, Egypt
#     Experience years : 3 - 5 Yrs of Exp
#     Skills are       : Python, AI
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : AI Engineer - The Flex Asia
#     Company name is  : The Flex - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : AI, Information Technology (IT), Computer Science, Engineering, Python, Software Engineering, NLP
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : R&D Manager
#     Company name is  : Midea Group - in Alsadat City, Monufya, Egypt
#     Experience years : N/A
#     Skills are       : R&D, Customer Service, Team Leadership
#     Published in     : 6 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : AI Engineer - Asia
#     Company name is  : The Flex - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : AI, Information Technology (IT), Computer Science, Engineering, Python, Software Engineering, NLP
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : AI DESIGN ARCHITECT
#     Company name is  : AL ROUKN ENGINEERING CONSULTANT - in Heliopolis, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : AI Integration, Architectural Design, Digital Prototyping, Technical Documentation
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Data Management Engineer
#     Company name is  : MOBILY INFOTECH LTD INDIA - in New Cairo, Cairo, Egypt
#     Experience years : 8 - 10 Yrs of Exp
#     Skills are       : Data Management, Informatica, Axon, EDC, DATA PROTECTION
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Printing Engineer
#     Company name is  : Sidhom Printing Solutions  - in Nasr City, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Process troubleshooting, Printing machinery operation, Preventive maintenance, Technical documentation, Quality control, Problem-solving, Team collaboration, Attention to detail, Time management
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Chatbot Developer
#     Company name is  : MOBILY INFOTECH LTD INDIA - in New Cairo, Cairo, Egypt
#     Experience years : 5 - 7 Yrs of Exp
#     Skills are       : chatbot, Chatbot developer, Computer Science, Software Development, Information Technology (IT)
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : MLOps Engineer
#     Company name is  : Confidential - in Cairo, Egypt
#     Experience years : 5 - 9 Yrs of Exp
#     Skills are       : Cloudera, MLOps, MLflow, Hadoop
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : ML Data Engineer
#     Company name is  : Confidential - in Cairo, Egypt
#     Experience years : 7 - 10 Yrs of Exp
#     Skills are       : Python, Cloudera, Hadoop, Hive, Spark, HDFS, Azure Data Lake, PySpark
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Senior Data Analyst
#     Company name is  : Xceed Contact Center - in Cairo, Egypt
#     Experience years : 3+ Yrs of Exp
#     Skills are       : ETL, Data Analysis, Communication skills, Python, SQL, Business Intelligence, PowerBI, Pandas
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Sales and Marketing Coordinator
#     Company name is  : Vendy Station - in Nasr City, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Communication, Sales, Design, Organizational Structure, costumer service
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Software Engineer (AI & Data Analytics)
#     Company name is  : Confidential - in Maadi, Cairo, Egypt
#     Experience years : 3 - 6 Yrs of Exp
#     Skills are       : Analysis, Information Technology (IT), Cloud, Software Engineering, Software Development, Java, Programming, AWS
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : QA Validation & Qualification Officer
#     Company name is  : APEX Pharma - in Badr City, Cairo, Egypt
#     Experience years : 3+ Yrs of Exp
#     Skills are       : Pharmaceutical, Quality Assurance, Pharmacy, Science
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : NLP Python Engineer
#     Company name is  : Confidential - in Cairo, Egypt
#     Experience years : 5 - 8 Yrs of Exp
#     Skills are       : AI, Software Development, Software Engineering, Agile Software Development, PyTorch, TensorFlow, Keras
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Senior Android Developer
#     Company name is  : Madar Soft - in Fleming, Alexandria, Egypt
#     Experience years : 3 - 3 Yrs of Exp
#     Skills are       : APIs, Computer Science, Design, Android, Software Engineering, Git, Information Technology (IT), Java
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Enterprise Data Warehouse and Business intelligence Engineer (Microsoft Technology SSIS-SSAS)
#     Company name is  : The Micro, Small & Medium Enterprise Development Agency  - in Dokki, Giza, Egypt
#     Experience years : N/A
#     Skills are       : BI, Business Intelligence, Data Warehousing, Power BI, SSAS, SSIS, Computer Science, Data Analysis, Engineering
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : MLOps + AI Engineer
#     Company name is  : Confidential - in Cairo, Egypt
#     Experience years : 7 - 8 Yrs of Exp
#     Skills are       : Git, Azure DevOps, Azure Pipelines, DVC, Azure ML, SonarQube, pytest, Grafana, Docker
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Backend Developer
#     Company name is  : Confidential - in Cairo, Egypt
#     Experience years : 4 - 6 Yrs of Exp
#     Skills are       : APIs, Computer Science, back-end, Git, Information Technology (IT), Laravel, Software Development, Software Engineering
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : AI Engineering Manager
#     Company name is  : Link Development - in Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Computer Science, BI, Software Engineering, SQL, Software Development, Power BI, SSRS
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Senior Cost Accountant (Manufacturing Industry)
#     Company name is  : Selah ElTelmeez For Publishing & printing - in Obour City, Cairo, Egypt
#     Experience years : 4 - 6 Yrs of Exp
#     Skills are       : Accounting, analytical, Communication, Cost Accounting, ERP System, Finance, Financial Management, Cost, ERP
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Software Development Manager
#     Company name is  : Confidential - in 6th of October, Giza, Egypt
#     Experience years : N/A
#     Skills are       : Azure, Computer Science, developer, Engineering, ERP System, Information Technology (IT), ERP
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Pavement Assessment Engineer
#     Company name is  : Citylogix ME   - in New Cairo, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Engineering, Communication, Pavement, Roads, English, quality
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Senior AI Engineer
#     Company name is  : Link Development - in Cairo, Egypt
#     Experience years : 2 - 5 Yrs of Exp
#     Skills are       : Computer Science, BI, Software Engineering, SQL, Software Development, Power BI, SSRS, SQL Server
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Gaming Attendant - Elizabeth Tavern
#     Company name is  : Endeavour Group - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : education, teaching, english, marketing, gaming, communication, development
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Senior GIS Technician
#     Company name is  : Citylogix ME   - in New Cairo, Cairo, Egypt
#     Experience years : 5 - 10 Yrs of Exp
#     Skills are       : Arc GIS, GIS, QGIS
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Annotation Specialist
#     Company name is  : Abwab.ai - in Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Time Management, Communication, Analytical & Attention to Detail, Adaptability
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Production Internship - Alexandria
#     Company name is  : Prometeon tyres group – Egypt - in Ameria, Alexandria, Egypt
#     Experience years : N/A
#     Skills are       : Science, Production, Mechanical Engineering, Engineering, Chemistry, Media Production, quality
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Data Engineer Team Lead
#     Company name is  : COB Solution  - in Maadi, Cairo, Egypt
#     Experience years : N/A
#     Skills are       : Computer Science, Engineering, Data, Information Technology (IT), Software, Computer Engineering, AWS, Azure, Java
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Production Chemist
#     Company name is  : Intertrade Co.  - in 10th of Ramadan City, Sharqia, Egypt
#     Experience years : 2 - 4 Yrs of Exp
#     Skills are       : Chemistry, quality, Communication skills, Microsoft Excel, Science, Testing, Engineering
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Senior Full Stack Developer
#     Company name is  : Helios Towers - in Dubai, United Arab Emirates
#     Experience years : 10+ Yrs of Exp
#     Skills are       : Information Technology (IT), Computer Science, Software Development, javaScript, CSS, HTML, Full Stack
#     Published in     : 8 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Tailor
#     Company name is  : Miraval Resorts & Spas - in Riyadh, Saudi Arabia
#     Experience years : 5 - 10 Yrs of Exp
#     Skills are       : sales, sales skills, customer service, sales target, english, management, training
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Credit Analyst
#     Company name is  : Tamara - in Riyadh, Saudi Arabia
#     Experience years : 2 - 5 Yrs of Exp
#     Skills are       : Finance, Accounting, Financial Analysis, Credit, Analysis, Banking, Credit Analysis
#     Published in     : 13 hours ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Data Science Intern
#     Company name is  : Mozn - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : Administration, Data Entry, Microsoft Office, Data Science, Information Technology (IT), Computer Science, Science
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Junior Ads Specialist
#     Company name is  : Canonical - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : Marketing, Social Media, E-marketing, Microsoft Office, Digital Marketing, Media, Market Research
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Linux System Engineer - QA, Tooling, Automation
#     Company name is  : Canonical - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : Information Technology (IT), Computer Science, Engineering, Linux, Computer Engineering, System Administration, Installation
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Part-time Search Analyst Saudi Arabia
#     Company name is  : TELUS Digital AI Data Solutions - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : computer science, information technology (it), engineering, sql, analyst, content, media
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Front Desk Agent
#     Company name is  : Hyde Johannesburg Rosebank - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : Administration, Office Management, Front Desk, Microsoft Office, Admin, Customer Service, Secretary
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Part time Search Analyst Saudi Arabia
#     Company name is  : TELUS Digital - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : computer science, information technology (it), engineering, sql, analyst, content, media
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Part time Search Analyst Saudi Arabia
#     Company name is  : TELUS Digital AI Data Solutions - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : computer science, information technology (it), engineering, sql, analyst, content, media
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#     Job title is     : Media Search Analyst - Arabic
#     Company name is  : TELUS Digital AI Data Solutions - in Riyadh, Saudi Arabia
#     Experience years : N/A
#     Skills are       : Research, Social Media, Media, Analysis, Marketing, Writing, E-marketing
#     Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup

for page in range(4): 
    url = f'https://wuzzuf.net/search/jobs?a=spbg&q=machine%20learning&start={page}'
    Response = requests.get(url)
    soup = BeautifulSoup(Response.text, 'lxml')
    
    jobs = soup.find_all('div', class_='css-ghe2tq e1v1l3u10')
    print("The Server's Response =", Response,'\n')
    print('Found', len(jobs), 'jobs on page', page, '\n')

    for job in jobs:  
        job_title = job.find('h2', class_='css-193uk2c')
        job_title = job_title.text.strip() if job_title else "N/A"

        company_name = job.find('a', class_='css-ipsyv7')
        company_name = company_name.text.strip() if company_name else "N/A"

        site = job.find('span', class_='css-16x61xq')
        site = site.text.strip() if site else "N/A"

        skills_list = job.find_all('a', class_='css-5x9pm1')
        if skills_list:
            skills = ', '.join([skill.text.replace('·', '').strip() for skill in skills_list if skill.text.strip()])
        else:
            skills = "N/A"

        puplished_date = job.find('div', class_='css-eg55jf')
        puplished_date = puplished_date.text.strip() if puplished_date else "N/A"

        exp_anchor = job.find('a', class_='css-o171kl', string='Experienced')
        if exp_anchor:
            experience_span = exp_anchor.find_next('span')
            experience = experience_span.text.replace('·', '').strip() if experience_span else "N/A"
        else:
            experience = "N/A"

        print('''
        Job title is     : {} 
        Company name is  : {} in {} 
        Experience years : {} 
        Skills are       : {} 
        Published in     : {}
        '''.format(job_title, company_name, site, experience, skills, puplished_date))
        print('------------------------------------------------------------------------------------------------------------------\n')
# Out:
# The Server's Response = <Response [200]>
#
# Found 15 jobs on page 0
#
#
#         Job title is     : AI / Machine Learning Developer
#         Company name is  : Roboeyetec - in Nasr City, Cairo, Egypt
#         Experience years : 3 - 5 Yrs of Exp
#         Skills are       : Machine Learning Developer, Machine Learning, AI, Software Development
#         Published in     : 8 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Senior Machine Learning
#         Company name is  : Zeidex - in Giza, Egypt
#         Experience years : 3 - 5 Yrs of Exp
#         Skills are       : Machine Learning, Cloud Computing, PyTorch, Data Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Senior Quantitative Analyst
#         Company name is  : Confidential - in Cairo, Egypt
#         Experience years : 7+ Yrs of Exp
#         Skills are       : Statistical Analysis, Machine Learning, Programming (Python, R, C++, MATLAB), Quantitative Research, Backtesting, Risk Management, Data Analysis
#         Published in     : 11 hours ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Science Instructor
#         Company name is  : EpsilonAI - in Nasr City, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Data Science, Computer Science, Computer Engineering, Python, Machine Learning, Deep Learning, Artificial Intelligence (AI)
#         Published in     : 7 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Researcher / AI Engineer
#         Company name is  : Arabian Data - in Nasr City, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Machine Learning, Natural Language Processing, Deep Learning, Artificial Intelligence, Computer Vision, Data Engineering, Statistical Modeling
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Software Engineer
#         Company name is  : Arabian Data - in Nasr City, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Software Development, Data Engineering, Python, Machine Learning, ETL Processes, Front-End Development, front-end web development, Back-End Development
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Technical Lead
#         Company name is  : Zeidex - in Maadi, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Information Technology (IT), Software, Software Development, Development, Engineering, Software Engineering, Architecture
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Artificial Intelligence & Machine Learning Intern
#         Company name is  : Aajil - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : Artificial Intelligence, Computer Science, Information Technology (IT), Software Engineering, Software Development, Computer Engineering, Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Engineer - Travel Tech
#         Company name is  : Rahala - in Mohandessin, Giza, Egypt
#         Experience years : 2+ Yrs of Exp
#         Skills are       : AI, Computer Science, Data Science, Engineering, Information Technology (IT), Machine Learning, Python
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Scientist
#         Company name is  : Lumin - in Sheikh Zayed, Giza, Egypt
#         Experience years : 3+ Yrs of Exp
#         Skills are       : Computer Science, Analysis, Mathematics, Data Analysis, Hadoop, Data Science, Information Technology (IT)
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Scientist
#         Company name is  : Egabi FSI  - in Sheraton, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Computer Science, Data Mining, Data Science, data scientist, Hadoop, Machine Learning, Python, SQL
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Machine Learning Engineer
#         Company name is  : EPAM Systems - in Dubai, United Arab Emirates
#         Experience years : Machine Learning
#         Skills are       : Machine Learning, Computer Science, Information Technology (IT), Python, Software Engineering, Computer Engineering, Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Engineer
#         Company name is  : ProVision Group - in Maadi, Cairo, Egypt
#         Experience years : 2 - 7 Yrs of Exp
#         Skills are       : AI, Computer Vision, Data Science, Machine Learning
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Learning & Development Specialist
#         Company name is  : Sungrow MENA & Central Asia - in Dubai, United Arab Emirates
#         Experience years : Learning
#         Skills are       : Education, Learning, Training, Information Technology (IT), Computer Science, Teaching, E-Learning
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Learning & Development Manager - LXR Eastern Mangroves Abu Dhabi (Pre-Opening)
#         Company name is  : Hilton - in Dubai, United Arab Emirates
#         Experience years : N/A
#         Skills are       : Education, Learning, Training, Information Technology (IT), Computer Science, Teaching, E-Learning
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
# The Server's Response = <Response [200]>
#
# Found 15 jobs on page 1
#
#
#         Job title is     : AI Engineer
#         Company name is  : Sprint Star - in Cairo, Egypt
#         Experience years : 3 - 5 Yrs of Exp
#         Skills are       : Python, AI
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Engineer - The Flex Asia
#         Company name is  : The Flex - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : AI, Information Technology (IT), Computer Science, Engineering, Python, Software Engineering, NLP
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : R&D Manager
#         Company name is  : Midea Group - in Alsadat City, Monufya, Egypt
#         Experience years : N/A
#         Skills are       : R&D, Customer Service, Team Leadership
#         Published in     : 6 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Engineer - Asia
#         Company name is  : The Flex - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : AI, Information Technology (IT), Computer Science, Engineering, Python, Software Engineering, NLP
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI DESIGN ARCHITECT
#         Company name is  : AL ROUKN ENGINEERING CONSULTANT - in Heliopolis, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : AI Integration, Architectural Design, Digital Prototyping, Technical Documentation
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Management Engineer
#         Company name is  : MOBILY INFOTECH LTD INDIA - in New Cairo, Cairo, Egypt
#         Experience years : 8 - 10 Yrs of Exp
#         Skills are       : Data Management, Informatica, Axon, EDC, DATA PROTECTION
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Printing Engineer
#         Company name is  : Sidhom Printing Solutions  - in Nasr City, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Process troubleshooting, Printing machinery operation, Preventive maintenance, Technical documentation, Quality control, Problem-solving, Team collaboration, Attention to detail, Time management
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Chatbot Developer
#         Company name is  : MOBILY INFOTECH LTD INDIA - in New Cairo, Cairo, Egypt
#         Experience years : 5 - 7 Yrs of Exp
#         Skills are       : chatbot, Chatbot developer, Computer Science, Software Development, Information Technology (IT)
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : MLOps Engineer
#         Company name is  : Confidential - in Cairo, Egypt
#         Experience years : 5 - 9 Yrs of Exp
#         Skills are       : Cloudera, MLOps, MLflow, Hadoop
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : ML Data Engineer
#         Company name is  : Confidential - in Cairo, Egypt
#         Experience years : 7 - 10 Yrs of Exp
#         Skills are       : Python, Cloudera, Hadoop, Hive, Spark, HDFS, Azure Data Lake, PySpark
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Senior Data Analyst
#         Company name is  : Xceed Contact Center - in Cairo, Egypt
#         Experience years : 3+ Yrs of Exp
#         Skills are       : ETL, Data Analysis, Communication skills, Python, SQL, Business Intelligence, PowerBI, Pandas
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Sales and Marketing Coordinator
#         Company name is  : Vendy Station - in Nasr City, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Communication, Sales, Design, Organizational Structure, costumer service
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Software Engineer (AI & Data Analytics)
#         Company name is  : Confidential - in Maadi, Cairo, Egypt
#         Experience years : 3 - 6 Yrs of Exp
#         Skills are       : Analysis, Information Technology (IT), Cloud, Software Engineering, Software Development, Java, Programming, AWS
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : QA Validation & Qualification Officer
#         Company name is  : APEX Pharma - in Badr City, Cairo, Egypt
#         Experience years : 3+ Yrs of Exp
#         Skills are       : Pharmaceutical, Quality Assurance, Pharmacy, Science
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : NLP Python Engineer
#         Company name is  : Confidential - in Cairo, Egypt
#         Experience years : 5 - 8 Yrs of Exp
#         Skills are       : AI, Software Development, Software Engineering, Agile Software Development, PyTorch, TensorFlow, Keras
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
# The Server's Response = <Response [200]>
#
# Found 15 jobs on page 2
#
#
#         Job title is     : Senior Android Developer
#         Company name is  : Madar Soft - in Fleming, Alexandria, Egypt
#         Experience years : 3 - 3 Yrs of Exp
#         Skills are       : APIs, Computer Science, Design, Android, Software Engineering, Git, Information Technology (IT), Java
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Enterprise Data Warehouse and Business intelligence Engineer (Microsoft Technology SSIS-SSAS)
#         Company name is  : The Micro, Small & Medium Enterprise Development Agency  - in Dokki, Giza, Egypt
#         Experience years : N/A
#         Skills are       : BI, Business Intelligence, Data Warehousing, Power BI, SSAS, SSIS, Computer Science, Data Analysis, Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : MLOps + AI Engineer
#         Company name is  : Confidential - in Cairo, Egypt
#         Experience years : 7 - 8 Yrs of Exp
#         Skills are       : Git, Azure DevOps, Azure Pipelines, DVC, Azure ML, SonarQube, pytest, Grafana, Docker
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Backend Developer
#         Company name is  : Confidential - in Cairo, Egypt
#         Experience years : 4 - 6 Yrs of Exp
#         Skills are       : APIs, Computer Science, back-end, Git, Information Technology (IT), Laravel, Software Development, Software Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Engineering Manager
#         Company name is  : Link Development - in Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Computer Science, BI, Software Engineering, SQL, Software Development, Power BI, SSRS
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Senior Cost Accountant (Manufacturing Industry)
#         Company name is  : Selah ElTelmeez For Publishing & printing - in Obour City, Cairo, Egypt
#         Experience years : 4 - 6 Yrs of Exp
#         Skills are       : Accounting, analytical, Communication, Cost Accounting, ERP System, Finance, Financial Management, Cost, ERP
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Software Development Manager
#         Company name is  : Confidential - in 6th of October, Giza, Egypt
#         Experience years : N/A
#         Skills are       : Azure, Computer Science, developer, Engineering, ERP System, Information Technology (IT), ERP
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Pavement Assessment Engineer
#         Company name is  : Citylogix ME   - in New Cairo, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Engineering, Communication, Pavement, Roads, English, quality
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Senior AI Engineer
#         Company name is  : Link Development - in Cairo, Egypt
#         Experience years : 2 - 5 Yrs of Exp
#         Skills are       : Computer Science, BI, Software Engineering, SQL, Software Development, Power BI, SSRS, SQL Server
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Gaming Attendant - Elizabeth Tavern
#         Company name is  : Endeavour Group - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : education, teaching, english, marketing, gaming, communication, development
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Senior GIS Technician
#         Company name is  : Citylogix ME   - in New Cairo, Cairo, Egypt
#         Experience years : 5 - 10 Yrs of Exp
#         Skills are       : Arc GIS, GIS, QGIS
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Annotation Specialist
#         Company name is  : Abwab.ai - in Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Time Management, Communication, Analytical & Attention to Detail, Adaptability
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Production Internship - Alexandria
#         Company name is  : Prometeon tyres group – Egypt - in Ameria, Alexandria, Egypt
#         Experience years : N/A
#         Skills are       : Science, Production, Mechanical Engineering, Engineering, Chemistry, Media Production, quality
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Engineer Team Lead
#         Company name is  : COB Solution  - in Maadi, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Computer Science, Engineering, Data, Information Technology (IT), Software, Computer Engineering, AWS, Azure, Java
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Production Chemist
#         Company name is  : Intertrade Co.  - in 10th of Ramadan City, Sharqia, Egypt
#         Experience years : 2 - 4 Yrs of Exp
#         Skills are       : Chemistry, quality, Communication skills, Microsoft Excel, Science, Testing, Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
# The Server's Response = <Response [200]>
#
# Found 11 jobs on page 3
#
#
#         Job title is     : Senior Full Stack Developer
#         Company name is  : Helios Towers - in Dubai, United Arab Emirates
#         Experience years : 10+ Yrs of Exp
#         Skills are       : Information Technology (IT), Computer Science, Software Development, javaScript, CSS, HTML, Full Stack
#         Published in     : 8 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Tailor
#         Company name is  : Miraval Resorts & Spas - in Riyadh, Saudi Arabia
#         Experience years : 5 - 10 Yrs of Exp
#         Skills are       : sales, sales skills, customer service, sales target, english, management, training
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Credit Analyst
#         Company name is  : Tamara - in Riyadh, Saudi Arabia
#         Experience years : 2 - 5 Yrs of Exp
#         Skills are       : Finance, Accounting, Financial Analysis, Credit, Analysis, Banking, Credit Analysis
#         Published in     : 13 hours ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Science Intern
#         Company name is  : Mozn - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : Administration, Data Entry, Microsoft Office, Data Science, Information Technology (IT), Computer Science, Science
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Junior Ads Specialist
#         Company name is  : Canonical - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : Marketing, Social Media, E-marketing, Microsoft Office, Digital Marketing, Media, Market Research
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Linux System Engineer - QA, Tooling, Automation
#         Company name is  : Canonical - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : Information Technology (IT), Computer Science, Engineering, Linux, Computer Engineering, System Administration, Installation
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Part-time Search Analyst Saudi Arabia
#         Company name is  : TELUS Digital AI Data Solutions - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : computer science, information technology (it), engineering, sql, analyst, content, media
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Front Desk Agent
#         Company name is  : Hyde Johannesburg Rosebank - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : Administration, Office Management, Front Desk, Microsoft Office, Admin, Customer Service, Secretary
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Part time Search Analyst Saudi Arabia
#         Company name is  : TELUS Digital - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : computer science, information technology (it), engineering, sql, analyst, content, media
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Part time Search Analyst Saudi Arabia
#         Company name is  : TELUS Digital AI Data Solutions - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : computer science, information technology (it), engineering, sql, analyst, content, media
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Media Search Analyst - Arabic
#         Company name is  : TELUS Digital AI Data Solutions - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : Research, Social Media, Media, Analysis, Marketing, Writing, E-marketing
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------

# %%
import requests
Response = requests.get('https://wuzzuf.net/search/jobs?a=spbg&q=machine%20learning')
print("The Server's Response = ", Response,'\n')

from bs4 import BeautifulSoup
soup = BeautifulSoup(Response.text, 'lxml')

jobs = soup.find_all('div', class_= 'css-ghe2tq e1v1l3u10')
print('Found',len(jobs),'jobs\n')

for job in jobs:
    job_title = job.find('h2', class_='css-193uk2c')
    job_title = job_title.text.strip() if job_title else "N/A"

    company_name = job.find('a', class_='css-ipsyv7')
    company_name = company_name.text.strip() if company_name else "N/A"

    site = job.find('span', class_='css-16x61xq')
    site = site.text.strip() if site else "N/A"

    skills_list = job.find_all('a', class_='css-5x9pm1')
    if skills_list:
        skills = ', '.join([skill.text.replace('·', '').strip() for skill in skills_list if skill.text.strip()])
    else:
        skills = "N/A"

    puplished_date = job.find('div', class_='css-eg55jf')
    puplished_date = puplished_date.text.strip() if puplished_date else "N/A"

    exp_anchor = job.find('a', class_='css-o171kl', string='Experienced')
    if exp_anchor:
        experience_span = exp_anchor.find_next('span')
        experience = experience_span.text.replace('·', '').strip() if experience_span else "N/A"
    else:
         experience = "N/A"
            

    if job_title and  company_name and site and experience and skills and puplished_date :
        print('''
        Job title is     : {} 
        Company name is  : {} in {} 
        Experience years : {} 
        Skills are       : {} 
        Published in     : {}
        '''.format(job_title, company_name, site, experience, skills, puplished_date))
       
        print('------------------------------------------------------------------------------------------------------------------\n')
# Out:
# The Server's Response =  <Response [200]>
#
# Found 15 jobs
#
#
#         Job title is     : AI / Machine Learning Developer
#         Company name is  : Roboeyetec - in Nasr City, Cairo, Egypt
#         Experience years : 3 - 5 Yrs of Exp
#         Skills are       : Machine Learning Developer, Machine Learning, AI, Software Development
#         Published in     : 8 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Senior Machine Learning
#         Company name is  : Zeidex - in Giza, Egypt
#         Experience years : 3 - 5 Yrs of Exp
#         Skills are       : Machine Learning, Cloud Computing, PyTorch, Data Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Senior Quantitative Analyst
#         Company name is  : Confidential - in Cairo, Egypt
#         Experience years : 7+ Yrs of Exp
#         Skills are       : Statistical Analysis, Machine Learning, Programming (Python, R, C++, MATLAB), Quantitative Research, Backtesting, Risk Management, Data Analysis
#         Published in     : 10 hours ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Science Instructor
#         Company name is  : EpsilonAI - in Nasr City, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Data Science, Computer Science, Computer Engineering, Python, Machine Learning, Deep Learning, Artificial Intelligence (AI)
#         Published in     : 7 days ago
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Researcher / AI Engineer
#         Company name is  : Arabian Data - in Nasr City, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Machine Learning, Natural Language Processing, Deep Learning, Artificial Intelligence, Computer Vision, Data Engineering, Statistical Modeling
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Software Engineer
#         Company name is  : Arabian Data - in Nasr City, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Software Development, Data Engineering, Python, Machine Learning, ETL Processes, Front-End Development, front-end web development, Back-End Development
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Technical Lead
#         Company name is  : Zeidex - in Maadi, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Information Technology (IT), Software, Software Development, Development, Engineering, Software Engineering, Architecture
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Artificial Intelligence & Machine Learning Intern
#         Company name is  : Aajil - in Riyadh, Saudi Arabia
#         Experience years : N/A
#         Skills are       : Artificial Intelligence, Computer Science, Information Technology (IT), Software Engineering, Software Development, Computer Engineering, Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Engineer - Travel Tech
#         Company name is  : Rahala - in Mohandessin, Giza, Egypt
#         Experience years : 2+ Yrs of Exp
#         Skills are       : AI, Computer Science, Data Science, Engineering, Information Technology (IT), Machine Learning, Python
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Scientist
#         Company name is  : Lumin - in Sheikh Zayed, Giza, Egypt
#         Experience years : 3+ Yrs of Exp
#         Skills are       : Computer Science, Analysis, Mathematics, Data Analysis, Hadoop, Data Science, Information Technology (IT)
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Data Scientist
#         Company name is  : Egabi FSI  - in Sheraton, Cairo, Egypt
#         Experience years : N/A
#         Skills are       : Computer Science, Data Mining, Data Science, data scientist, Hadoop, Machine Learning, Python, SQL
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Machine Learning Engineer
#         Company name is  : EPAM Systems - in Dubai, United Arab Emirates
#         Experience years : Machine Learning
#         Skills are       : Machine Learning, Computer Science, Information Technology (IT), Python, Software Engineering, Computer Engineering, Engineering
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : AI Engineer
#         Company name is  : ProVision Group - in Maadi, Cairo, Egypt
#         Experience years : 2 - 7 Yrs of Exp
#         Skills are       : AI, Computer Vision, Data Science, Machine Learning
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Learning & Development Specialist
#         Company name is  : Sungrow MENA & Central Asia - in Dubai, United Arab Emirates
#         Experience years : Learning
#         Skills are       : Education, Learning, Training, Information Technology (IT), Computer Science, Teaching, E-Learning
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
#
#
#         Job title is     : Learning & Development Manager - LXR Eastern Mangroves Abu Dhabi (Pre-Opening)
#         Company name is  : Hilton - in Dubai, United Arab Emirates
#         Experience years : N/A
#         Skills are       : Education, Learning, Training, Information Technology (IT), Computer Science, Teaching, E-Learning
#         Published in     : N/A
#
# ------------------------------------------------------------------------------------------------------------------
